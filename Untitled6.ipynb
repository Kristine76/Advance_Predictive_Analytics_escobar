# %% [markdown]
# <a href="https://colab.research.google.com/github/Kristine76/Advance_Predictive_Analytics_escobar/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


df=pd.read_csv("https://raw.githubusercontent.com/Kristine76/DATA-SET/main/daily-minimum-temperatures-in-me.csv")


df.head()
# Out:
#        Date Daily minimum temperatures
# 0  1/1/1981                       20.7
# 1  1/2/1981                       17.9
# 2  1/3/1981                       18.8
# 3  1/4/1981                       14.6
# 4  1/5/1981                       15.8

# %%
date_rng = pd.date_range(start='01-01-1985',end='05-01-1985',freq='D')


time_series_data = pd.Series(range(0,11))


df.head()
# Out:
#        Date Daily minimum temperatures
# 0  1/1/1981                       20.7
# 1  1/2/1981                       17.9
# 2  1/3/1981                       18.8
# 3  1/4/1981                       14.6
# 4  1/5/1981                       15.8

# %%
date_rng = pd.date_range(start='01-01-1985',end='05-01-1985',freq='D')


time_series_data = pd.Series(range(0,11))


df
# Out:
#             Date Daily minimum temperatures
# 0       1/1/1981                       20.7
# 1       1/2/1981                       17.9
# 2       1/3/1981                       18.8
# 3       1/4/1981                       14.6
# 4       1/5/1981                       15.8
# ...          ...                        ...
# 3645  12/27/1990                         14
# 3646  12/28/1990                       13.6
# 3647  12/29/1990                       13.5
# 3648  12/30/1990                       15.7
# 3649  12/31/1990                         13
#
# [3650 rows x 2 columns]

# %%
import matplotlib.pyplot as plt


time_series_data_trend = time_series_data + 0.5 * pd.Series(range(0,11))


df
# Out:
#             Date Daily minimum temperatures
# 0       1/1/1981                       20.7
# 1       1/2/1981                       17.9
# 2       1/3/1981                       18.8
# 3       1/4/1981                       14.6
# 4       1/5/1981                       15.8
# ...          ...                        ...
# 3645  12/27/1990                         14
# 3646  12/28/1990                       13.6
# 3647  12/29/1990                       13.5
# 3648  12/30/1990                       15.7
# 3649  12/31/1990                         13
#
# [3650 rows x 2 columns]
